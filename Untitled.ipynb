# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('analyse_2.csv')

# %%
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot
matplotlib.pyplot.figure() 
pyplot.figure(figsize=(15, 15))


sns.heatmap(df)

# %%
from analyse_coin import *

# %%
compute_all()
# Out:
# compute ('bitcoin', 'ripple')
# 0.48251305252 6.09675658718e-80
# compute ('bitcoin', 'ethereum')
# 0.810698996283 4.2171361582e-152
# compute ('bitcoin', 'litecoin')
# 0.552057954654 1.10537723466e-116
# compute ('bitcoin', 'nem')
# 0.701605814505 1.9358391243e-115
# compute ('bitcoin', 'dash')
# 0.79137261724 1.86537717612e-251
# compute ('bitcoin', 'ethereum-classic')
# 0.728986431044 1.75024191443e-50
# compute ('bitcoin', 'stellar')
# 0.367545136296 1.55768047171e-33
# compute ('bitcoin', 'monero')
# 0.908387235402 0.0
# compute ('bitcoin', 'steem')
# -0.254341473175 3.21575027464e-07
# compute ('bitcoin', 'golem-network-tokens')
# 0.850314382363 1.66532651452e-51
# compute ('bitcoin', 'augur')
# 0.467833904514 5.13393950105e-26
# compute ('bitcoin', 'gamecredits')
# 0.854840999409 1.70673889227e-273
# compute ('bitcoin', 'maidsafecoin')
# 0.88378741297 0.0
# compute ('bitcoin', 'round')
# 0.749664338669 1.18526424803e-32
# compute ('bitcoin', 'gnosis-gno')
# ...
